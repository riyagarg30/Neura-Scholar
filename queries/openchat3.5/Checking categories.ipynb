# %%
# !pip install torch torchvision tqdm numpy pandas sqlalchemy
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.12/site-packages (2.5.1+cpu)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.12/site-packages (0.20.1+cpu)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (2.0.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.12/site-packages (2.0.37)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.12/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: psycopg2-binary in /opt/conda/lib/python3.12/site-packages (2.9.10)

# %%
import os
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import numpy as np
from sqlalchemy import create_engine, text
import pandas as pd
import tarfile
import shutil
import re
import unicodedata
from tqdm import tqdm

# %%
engine = create_engine(
    'postgresql://rg5073:rg5073pass@129.114.27.3:5432/cleaned_meta_data_db',
    pool_size=10,
    max_overflow=0,
    pool_timeout=30,
)

# %%
query_preview = "SELECT * FROM arxiv_chunks_training_4 LIMIT 5;"
preview = pd.read_sql(query_preview, engine)
print(" Data:")
print(preview)
# Out:
#  Data:
#       paper_id chunk_no       chunk_id     txt_filename query  \
# 0  0704.1728v1     None  0704.1728v1_1  0704.1728v1.txt
# 1  0704.1728v1     None  0704.1728v1_2  0704.1728v1.txt
# 2  0704.1728v1     None  0704.1728v1_3  0704.1728v1.txt
# 3  0704.1728v1     None  0704.1728v1_4  0704.1728v1.txt
# 4  0704.1479v2     None  0704.1479v2_1  0704.1479v2.txt
#
#                                           chunk_data
# 0  arXiv 0704.1728v1 gr qc 13 Apr 2007 April 2007...
# 1  Z L q d . The Lagrangian L depends only on the...
# 2  involved form. We want now to investigate the ...
# 3  space, instead of configuration space, or perh...
# 4  arXiv 0704.1479v2 cond mat.mes hall 12 Apr 200...

# %%
import json
import pandas as pd

check_query = """
    SELECT paper_id, chunk_id, query
    FROM arxiv_chunks_training_4
    WHERE query IS NOT NULL
"""
df = pd.read_sql(check_query, engine)
df = df[df["query"].str.strip().ne("")]
df["query_list"] = df["query"].apply(json.loads)

df["query_count"] = df["query_list"].apply(len)
three_query_chunks = df[df["query_count"] == 3]

print(f"Total chunks with exactly 3 queries: {len(three_query_chunks)}")
# Out:
# Total chunks with exactly 3 queries: 6043

# %%
df_tables = pd.read_sql("""
    SELECT table_schema, table_name 
    FROM information_schema.tables 
    WHERE table_type = 'BASE TABLE'
    ORDER BY table_schema, table_name;
""", engine)
pd.set_option('display.max_rows', None)
print(df_tables)
# Out:
#           table_schema                       table_name
# 0   information_schema                     sql_features
# 1   information_schema          sql_implementation_info
# 2   information_schema                        sql_parts
# 3   information_schema                       sql_sizing
# 4           pg_catalog                     pg_aggregate
# 5           pg_catalog                            pg_am
# 6           pg_catalog                          pg_amop
# 7           pg_catalog                        pg_amproc
# 8           pg_catalog                       pg_attrdef
# 9           pg_catalog                     pg_attribute
# 10          pg_catalog                  pg_auth_members
# 11          pg_catalog                        pg_authid
# 12          pg_catalog                          pg_cast
# 13          pg_catalog                         pg_class
# 14          pg_catalog                     pg_collation
# 15          pg_catalog                    pg_constraint
# 16          pg_catalog                    pg_conversion
# 17          pg_catalog                      pg_database
# 18          pg_catalog               pg_db_role_setting
# 19          pg_catalog                   pg_default_acl
# 20          pg_catalog                        pg_depend
# 21          pg_catalog                   pg_description
# 22          pg_catalog                          pg_enum
# 23          pg_catalog                 pg_event_trigger
# 24          pg_catalog                     pg_extension
# 25          pg_catalog          pg_foreign_data_wrapper
# 26          pg_catalog                pg_foreign_server
# 27          pg_catalog                 pg_foreign_table
# 28          pg_catalog                         pg_index
# 29          pg_catalog                      pg_inherits
# 30          pg_catalog                    pg_init_privs
# 31          pg_catalog                      pg_language
# 32          pg_catalog                   pg_largeobject
# 33          pg_catalog          pg_largeobject_metadata
# 34          pg_catalog                     pg_namespace
# 35          pg_catalog                       pg_opclass
# 36          pg_catalog                      pg_operator
# 37          pg_catalog                      pg_opfamily
# 38          pg_catalog                 pg_parameter_acl
# 39          pg_catalog             pg_partitioned_table
# 40          pg_catalog                        pg_policy
# 41          pg_catalog                          pg_proc
# 42          pg_catalog                   pg_publication
# 43          pg_catalog         pg_publication_namespace
# 44          pg_catalog               pg_publication_rel
# 45          pg_catalog                         pg_range
# 46          pg_catalog            pg_replication_origin
# 47          pg_catalog                       pg_rewrite
# 48          pg_catalog                      pg_seclabel
# 49          pg_catalog                      pg_sequence
# 50          pg_catalog                      pg_shdepend
# 51          pg_catalog                 pg_shdescription
# 52          pg_catalog                    pg_shseclabel
# 53          pg_catalog                     pg_statistic
# 54          pg_catalog                 pg_statistic_ext
# 55          pg_catalog            pg_statistic_ext_data
# 56          pg_catalog                  pg_subscription
# 57          pg_catalog              pg_subscription_rel
# 58          pg_catalog                    pg_tablespace
# 59          pg_catalog                     pg_transform
# 60          pg_catalog                       pg_trigger
# 61          pg_catalog                     pg_ts_config
# 62          pg_catalog                 pg_ts_config_map
# 63          pg_catalog                       pg_ts_dict
# 64          pg_catalog                     pg_ts_parser
# 65          pg_catalog                   pg_ts_template
# 66          pg_catalog                          pg_type
# 67          pg_catalog                  pg_user_mapping
# 68              public                     arxiv_chunks
# 69              public            arxiv_chunks_training
# 70              public          arxiv_chunks_training_2
# 71              public          arxiv_chunks_training_3
# 72              public          arxiv_chunks_training_4
# 73              public          arxiv_chunks_training_5
# 74              public    arxiv_chunks_training_initial
# 75              public  arxiv_chunks_training_initial_1
# 76              public                   arxiv_metadata

# %%
with engine.connect() as conn:
    conn.execute(text("""
        DROP TABLE IF EXISTS arxiv_chunks_training_4_phrases1;
        CREATE TABLE arxiv_chunks_training_4_phrases1 AS 
        TABLE arxiv_chunks_training_4;
    """))
    conn.commit()

# %%
with engine.connect() as conn:
    conn.execute(text("""
        DROP TABLE IF EXISTS arxiv_chunks_training_4_phrases2;
        CREATE TABLE arxiv_chunks_training_4_phrases2 AS 
        TABLE arxiv_chunks_training_4;
    """))
    conn.commit()

# %%
df_tables = pd.read_sql("""
    SELECT table_schema, table_name 
    FROM information_schema.tables 
    WHERE table_type = 'BASE TABLE'
    ORDER BY table_schema, table_name;
""", engine)
pd.set_option('display.max_rows', None)
print(df_tables)
# Out:
#           table_schema                        table_name
# 0   information_schema                      sql_features
# 1   information_schema           sql_implementation_info
# 2   information_schema                         sql_parts
# 3   information_schema                        sql_sizing
# 4           pg_catalog                      pg_aggregate
# 5           pg_catalog                             pg_am
# 6           pg_catalog                           pg_amop
# 7           pg_catalog                         pg_amproc
# 8           pg_catalog                        pg_attrdef
# 9           pg_catalog                      pg_attribute
# 10          pg_catalog                   pg_auth_members
# 11          pg_catalog                         pg_authid
# 12          pg_catalog                           pg_cast
# 13          pg_catalog                          pg_class
# 14          pg_catalog                      pg_collation
# 15          pg_catalog                     pg_constraint
# 16          pg_catalog                     pg_conversion
# 17          pg_catalog                       pg_database
# 18          pg_catalog                pg_db_role_setting
# 19          pg_catalog                    pg_default_acl
# 20          pg_catalog                         pg_depend
# 21          pg_catalog                    pg_description
# 22          pg_catalog                           pg_enum
# 23          pg_catalog                  pg_event_trigger
# 24          pg_catalog                      pg_extension
# 25          pg_catalog           pg_foreign_data_wrapper
# 26          pg_catalog                 pg_foreign_server
# 27          pg_catalog                  pg_foreign_table
# 28          pg_catalog                          pg_index
# 29          pg_catalog                       pg_inherits
# 30          pg_catalog                     pg_init_privs
# 31          pg_catalog                       pg_language
# 32          pg_catalog                    pg_largeobject
# 33          pg_catalog           pg_largeobject_metadata
# 34          pg_catalog                      pg_namespace
# 35          pg_catalog                        pg_opclass
# 36          pg_catalog                       pg_operator
# 37          pg_catalog                       pg_opfamily
# 38          pg_catalog                  pg_parameter_acl
# 39          pg_catalog              pg_partitioned_table
# 40          pg_catalog                         pg_policy
# 41          pg_catalog                           pg_proc
# 42          pg_catalog                    pg_publication
# 43          pg_catalog          pg_publication_namespace
# 44          pg_catalog                pg_publication_rel
# 45          pg_catalog                          pg_range
# 46          pg_catalog             pg_replication_origin
# 47          pg_catalog                        pg_rewrite
# 48          pg_catalog                       pg_seclabel
# 49          pg_catalog                       pg_sequence
# 50          pg_catalog                       pg_shdepend
# 51          pg_catalog                  pg_shdescription
# 52          pg_catalog                     pg_shseclabel
# 53          pg_catalog                      pg_statistic
# 54          pg_catalog                  pg_statistic_ext
# 55          pg_catalog             pg_statistic_ext_data
# 56          pg_catalog                   pg_subscription
# 57          pg_catalog               pg_subscription_rel
# 58          pg_catalog                     pg_tablespace
# 59          pg_catalog                      pg_transform
# 60          pg_catalog                        pg_trigger
# 61          pg_catalog                      pg_ts_config
# 62          pg_catalog                  pg_ts_config_map
# 63          pg_catalog                        pg_ts_dict
# 64          pg_catalog                      pg_ts_parser
# 65          pg_catalog                    pg_ts_template
# 66          pg_catalog                           pg_type
# 67          pg_catalog                   pg_user_mapping
# 68              public                      arxiv_chunks
# 69              public             arxiv_chunks_training
# 70              public           arxiv_chunks_training_2
# 71              public           arxiv_chunks_training_3
# 72              public           arxiv_chunks_training_4
# 73              public  arxiv_chunks_training_4_phrases1
# 74              public  arxiv_chunks_training_4_phrases2
# 75              public           arxiv_chunks_training_5
# 76              public     arxiv_chunks_training_initial
# 77              public   arxiv_chunks_training_initial_1
# 78              public                    arxiv_metadata

# %%
with engine.connect() as conn:
    conn.execute(text("""
        DROP TABLE IF EXISTS arxiv_chunks_training_4_phrases1;

        CREATE TABLE arxiv_chunks_training_4_phrases1 AS
        SELECT *
        FROM arxiv_chunks_training_4
        WHERE 
            query IS NOT NULL
            AND query <> ''
            AND jsonb_typeof(query::jsonb) = 'array';
    """))
    conn.commit()

# %%
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("SELECT COUNT(*) FROM arxiv_chunks_training_4_phrases1;"))
    count = result.scalar()
    print(f"Num of records: {count}")
# Out:
# Num of records: 6043

# %%
with engine.connect() as conn:
    conn.execute(text("""
        DROP TABLE IF EXISTS arxiv_chunks_training_4_phrases2;

        CREATE TABLE arxiv_chunks_training_4_phrases2 AS
        SELECT *
        FROM arxiv_chunks_training_4
        WHERE 
            query IS NOT NULL
            AND query <> ''
            AND jsonb_typeof(query::jsonb) = 'array';
    """))
    conn.commit()

# %%
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("SELECT COUNT(*) FROM arxiv_chunks_training_4_phrases2;"))
    count = result.scalar()
    print(f"Num of records: {count}")
# Out:
# Num of records: 6043

# %%
inspect_query = """
    SELECT column_name, data_type
    FROM information_schema.columns
    WHERE table_name = 'arxiv_metadata'
    ORDER BY ordinal_position
"""

df_schema = pd.read_sql(inspect_query, engine)
print(df_schema)
# Out:
#        column_name data_type
# 0               id      text
# 1        submitter      text
# 2          authors      text
# 3            title      text
# 4         comments      text
# 5      journal_ref      text
# 6              doi      text
# 7         abstract      text
# 8        report_no      text
# 9       categories      text
# 10  latest_version      text
# 11    txt_filename      text
# 12    created_yymm      text

# %%
query_preview = "SELECT * FROM arxiv_chunks_training_4_phrases1 LIMIT 5;"
preview = pd.read_sql(query_preview, engine)
print(" Data:")
print(preview)
# Out:
#  Data:
#       paper_id chunk_no       chunk_id     txt_filename  \
# 0  0704.0107v1     None  0704.0107v1_5  0704.0107v1.txt
# 1  0704.0107v1     None  0704.0107v1_6  0704.0107v1.txt
# 2  0704.0107v1     None  0704.0107v1_7  0704.0107v1.txt
# 3  0704.0674v2     None  0704.0674v2_1  0704.0674v2.txt
# 4  0704.0674v2     None  0704.0674v2_2  0704.0674v2.txt
#
#                                                query  \
# 0  ["What is the Parzen's estimator formula used ...
# 1  ["How to adapt the model Eq. 19 to experimenta...
# 2  ["What is the effect of increasing T on the mo...
# 3  ["Galaxy alignment types", "Galaxy group catal...
# 4  ["What are the preferential distributions of s...
#
#                                           chunk_data
# 0  lim N 1 N N X x qi, , which we consider as the...
# 1  model relative to experimentally estimated fT ...
# 2  a new term with the parameters xT , , x g x xT...
# 3  arXiv 0704.0674v2 astro ph 8 Jun 2007 Draft ve...
# 4  neous samples. This has resulted in robust det...

# %% [markdown]
# Category of training data papers

# %%
query = """
    SELECT m.categories, COUNT(*) AS num_papers
    FROM arxiv_chunks_training_4_phrases1 t
    JOIN arxiv_metadata m ON t.paper_id = m.id
    GROUP BY m.categories
    ORDER BY num_papers DESC
"""

df = pd.read_sql(query, engine)
print(df)
# Out:
# Empty DataFrame
# Columns: [categories, num_papers]
# Index: []

# %%
query = """
    SELECT m.categories, COUNT(*) AS num_papers
    FROM arxiv_chunks_training_4_phrases1 t
    JOIN arxiv_metadata m ON split_part(t.paper_id, 'v', 1) = m.id
    GROUP BY m.categories
    ORDER BY num_papers DESC
"""
df = pd.read_sql(query, engine)
print(df)
# Out:
#                                             categories  num_papers
# 0                                         ['astro-ph']         808
# 1                                           ['hep-th']         322
# 2                                         ['quant-ph']         264
# 3                                           ['hep-ph']         245
# 4                                            ['gr-qc']         153
# 5                                          ['nucl-th']         144
# 6                                ['cond-mat.mes-hall']         139
# 7                                ['cond-mat.mtrl-sci']         137
# 8                                  ['cond-mat.str-el']         112
# 9                                           ['hep-ex']         102
# 10                                         ['math.AP']          85
# 11                                           ['cs.CC']          74
# 12                                  ['physics.optics']          69
# 13                                         ['math.AG']          64
# 14                                 ['math-ph math.MP']          61
# 15                                         ['math.GR']          59
# 16                                   ['cs.IT math.IT']          57
# 17                                         ['math.CO']          56
# 18                                         ['math.PR']          55
# 19                                  ['physics.gen-ph']          54
# 20                                  ['cond-mat.other']          53
# 21                           ['hep-th astro-ph gr-qc']          51
# 22                               ['cond-mat.supr-con']          50
# 23                                  ['hep-ph nucl-th']          49
# 24                                         ['nucl-ex']          45
# 25               ['cond-mat.mes-hall cond-mat.str-el']          45
# 26                                    ['hep-th gr-qc']          45
# 27               ['cond-mat.supr-con cond-mat.str-el']          45
# 28                                  ['physics.soc-ph']          41
# 29                                         ['math.SG']          40
# 30                                         ['math.OA']          40
# 31                                 ['math.PR math.AP']          40
# 32                                   ['hep-ph hep-ex']          38
# 33                         ['math.AP math-ph math.MP']          38
# 34                                         ['math.NA']          34
# 35                  ['physics.optics physics.comp-ph']          33
# 36                                         ['math.RA']          30
# 37              ['cond-mat.dis-nn cond-mat.stat-mech']          30
# 38             ['cond-mat.mes-hall cond-mat.mtrl-sci']          30
# 39                          ['hep-th math-ph math.MP']          30
# 40                                   ['hep-th hep-ph']          30
# 41                                 ['physics.chem-ph']          28
# 42                         ['math.AG math.AC math.RT']          28
# 43                                         ['math.AT']          27
# 44                                         ['math.QA']          27
# 45                              ['cond-mat.stat-mech']          27
# 46                                 ['math.AG math.CA']          26
# 47                                 ['nucl-th nucl-ex']          26
# 48                                   ['cond-mat.soft']          26
# 49                                 ['math.QA math.RT']          25
# 50                                         ['math.DS']          25
# 51                                 ['math.ST stat.TH']          25
# 52                                  ['gr-qc astro-ph']          25
# 53           ['cond-mat.soft nlin.PS physics.flu-dyn']          24
# 54               ['cond-mat.str-el cond-mat.mtrl-sci']          24
# 55              ['cond-mat.str-el cond-mat.stat-mech']          23
# 56                                         ['math.CV']          22
# 57                                    ['gr-qc hep-th']          22
# 58                                         ['math.NT']          22
# 59                 ['cond-mat.soft cond-mat.mtrl-sci']          21
# 60                 ['physics.flu-dyn physics.comp-ph']          20
# 61   ['quant-ph astro-ph cond-mat.stat-mech hep-ph ...          20
# 62                                  ['astro-ph gr-qc']          20
# 63                                         ['math.GT']          19
# 64                                 ['math.AT math.CT']          19
# 65                ['cond-mat.soft cond-mat.stat-mech']          18
# 66                                 ['quant-ph hep-th']          18
# 67   ['quant-ph hep-th nlin.CD physics.atom-ph phys...          18
# 68                      ['cond-mat.mes-hall quant-ph']          18
# 69                                   ['math.DG gr-qc']          18
# 70                 ['physics.data-an physics.comp-ph']          17
# 71                       ['math.PR q-fin.CP q-fin.PR']          17
# 72                             ['cs.NI cs.IT math.IT']          17
# 73                                         ['math.DG']          17
# 74                                 ['nucl-ex nucl-th']          17
# 75                                 ['math.AG math.CO']          17
# 76                                 ['physics.data-an']          17
# 77                          ['math-ph hep-th math.MP']          16
# 78                ['cond-mat.other cond-mat.mtrl-sci']          16
# 79                     ['cond-mat.stat-mech q-bio.NC']          16
# 80    ['cond-mat.supr-con cond-mat.mes-hall quant-ph']          16
# 81                 ['math.DS math-ph math.AP math.MP']          16
# 82                                 ['math.NA math.DS']          16
# 83                                 ['nlin.PS nlin.SI']          16
# 84                         ['math-ph math.DG math.MP']          15
# 85                                ['q-fin.PR math.PR']          14
# 86                                 ['math.DG math.GT']          14
# 87   ['math.PR cond-mat.stat-mech math-ph math.CO m...          14
# 88                           ['hep-ex hep-lat hep-ph']          14
# 89                                 ['math.CO math.DS']          13
# 90                                   ['math.CO cs.CG']          13
# 91                  ['physics.optics math-ph math.MP']          13
# 92            ['cond-mat.stat-mech cond-mat.mtrl-sci']          13
# 93                ['q-fin.GN physics.soc-ph q-fin.ST']          13
# 94                                         ['math.OC']          13
# 95                                  ['nucl-ex hep-ex']          13
# 96                               ['q-bio.PE q-bio.OT']          13
# 97   ['cond-mat.stat-mech cond-mat.soft physics.che...          12
# 98                                  ['physics.pop-ph']          12
# 99                          ['hep-ex astro-ph hep-ph']          12
# 100                                ['math.RT math.QA']          12
# 101                              ['q-bio.QM q-bio.MN']          12
# 102                         ['physics.ed-ph quant-ph']          12
# 103                                ['math.CV math.AC']          12
# 104                                ['math.AG math.CV']          12
# 105                         ['hep-ph hep-lat nucl-th']          12
# 106                          ['hep-lat hep-ph hep-th']          12
# 107                          ['gr-qc astro-ph hep-th']          11
# 108                                ['math.CA math.FA']          11
# 109                                    ['cs.NE cs.AI']          11
# 110           ['cond-mat.mtrl-sci cond-mat.stat-mech']          11
# 111                         ['hep-ph physics.atom-ph']          11
# 112                                       ['q-bio.NC']          11
# 113              ['cond-mat.mtrl-sci cond-mat.str-el']          11
# 114                                 ['nucl-th hep-ph']          11
# 115                   ['cs.IT cs.AI math.IT q-bio.PE']          11
# 116                       ['nlin.PS nlin.CD q-bio.PE']          11
# 117                                        ['math.FA']          10
# 118                       ['quant-ph math-ph math.MP']          10
# 119  ['q-fin.ST cond-mat.other physics.data-an phys...          10
# 120                      ['hep-th cond-mat.stat-mech']          10
# 121                                ['math.AC math.AG']          10
# 122                        ['physics.gen-ph q-bio.PE']          10
# 123                                ['physics.atom-ph']          10
# 124                                ['math.CO math.GT']          10
# 125              ['cond-mat.other cond-mat.stat-mech']          10
# 126          ['nlin.CD cond-mat.other physics.optics']          10
# 127                                ['math.DG math.RT']          10
# 128                                ['math.LO math.CO']          10
# 129                                ['math.FA math.SP']          10
# 130              ['cond-mat.stat-mech cond-mat.other']          10
# 131                                ['math.NT math.AG']           9
# 132                        ['math.PR math.ST stat.TH']           9
# 133                          ['astro-ph gr-qc hep-th']           9
# 134                                ['hep-th quant-ph']           9
# 135              ['cond-mat.str-el cond-mat.supr-con']           9
# 136               ['cond-mat.stat-mech cond-mat.soft']           9
# 137                 ['physics.data-an physics.gen-ph']           9
# 138            ['cond-mat.mtrl-sci cond-mat.mes-hall']           9
# 139            ['cond-mat.supr-con cond-mat.mtrl-sci']           9
# 140                                ['math.CO math.MG']           9
# 141                                ['math.GT math.QA']           9
# 142                          ['hep-ph hep-th nucl-th']           9
# 143                ['cond-mat.str-el cond-mat.dis-nn']           9
# 144                         ['astro-ph physics.ao-ph']           8
# 145                                          ['cs.CR']           8
# 146                                    ['cs.DM cs.LO']           8
# 147                                          ['cs.DS']           8
# 148                            ['cs.IT cs.LG math.IT']           8
# 149                                ['math.RT math.GR']           8
# 150                     ['quant-ph cond-mat.mes-hall']           8
# 151                                ['math.OA math.FA']           8
# 152                          ['hep-ph hep-ex nucl-ex']           8
# 153                                ['math.CA math.AT']           8
# 154                                    ['cs.CC cs.DS']           8
# 155              ['cond-mat.dis-nn cond-mat.mes-hall']           8
# 156                                ['math.KT math.RA']           8
# 157                                ['math.CO math.GR']           7
# 158                         ['hep-ph astro-ph hep-th']           7
# 159                                 ['hep-ph nucl-ex']           7
# 160                         ['hep-th astro-ph hep-ph']           7
# 161                                    ['cs.DS cs.PF']           7
# 162             ['cond-mat.stat-mech physics.ins-det']           7
# 163                  ['cond-mat.soft cond-mat.dis-nn']           7
# 164                         ['cond-mat.other nlin.PS']           7
# 165        ['q-bio.NC cond-mat.dis-nn physics.soc-ph']           7
# 166                               ['q-fin.CP math.PR']           7
# 167        ['quant-ph cond-mat.other physics.atom-ph']           7
# 168                ['physics.optics physics.class-ph']           6
# 169                                    ['cs.PF cs.NI']           6
# 170                   ['hep-th astro-ph gr-qc hep-ph']           6
# 171                            ['cs.IT cs.CC math.IT']           6
# 172                        ['math.DS math-ph math.MP']           6
# 173         ['math.QA hep-th math-ph math.MP math.RT']           6
# 174                                       ['q-bio.OT']           6
# 175                        ['gr-qc astro-ph quant-ph']           6
# 176                                ['math.AG math.KT']           6
# 177                                ['math.DG math.CA']           6
# 178                                ['math.NT math.RT']           6
# 179             ['math.ST cond-mat.stat-mech stat.TH']           6
# 180         ['physics.optics physics.gen-ph quant-ph']           6
# 181                                ['math.AP math.GM']           6
# 182                                        ['nlin.CG']           6
# 183       ['physics.optics physics.class-ph quant-ph']           6
# 184                                 ['physics.bio-ph']           6
# 185              ['nlin.SI cond-mat.stat-mech hep-th']           6
# 186                 ['cond-mat.other hep-th quant-ph']           6
# 187                                    ['cs.CC cs.DM']           6
# 188            ['cond-mat.supr-con cond-mat.mes-hall']           6
# 189                                ['math.OA math.KT']           6
# 190                               ['nucl-th quant-ph']           6
# 191                                ['math.CA math.PR']           6
# 192                 ['physics.atom-ph cond-mat.other']           6
# 193                ['physics.comp-ph physics.data-an']           6
# 194                 ['cond-mat.str-el cond-mat.other']           6
# 195        ['physics.bio-ph physics.data-an q-bio.BM']           5
# 196                        ['quant-ph cond-mat.other']           5
# 197              ['cond-mat.supr-con cond-mat.dis-nn']           5
# 198                                  ['hep-ex hep-ph']           5
# 199                  ['hep-ph hep-lat hep-th nucl-th']           5
# 200         ['cond-mat.other physics.optics quant-ph']           5
# 201              ['physics.plasm-ph physics.space-ph']           5
# 202                                 ['hep-lat hep-ph']           5
# 203                                ['math.FA math.AP']           5
# 204               ['nlin.PS physics.chem-ph q-bio.MN']           5
# 205  ['physics.optics cond-mat.soft nlin.PS physics...           5
# 206                                       ['q-bio.PE']           5
# 207                        ['math.PR math-ph math.MP']           5
# 208                   ['astro-ph gr-qc hep-ph hep-th']           5
# 209             ['cond-mat.stat-mech cond-mat.dis-nn']           5
# 210                ['cond-mat.soft cond-mat.supr-con']           5
# 211                                ['hep-ph astro-ph']           5
# 212               ['physics.flu-dyn physics.plasm-ph']           5
# 213               ['cond-mat.mtrl-sci cond-mat.other']           5
# 214                         ['nucl-th hep-ph nucl-ex']           5
# 215                         ['quant-ph cs.IT math.IT']           5
# 216                                       ['q-bio.BM']           5
# 217                                        ['math.RT']           5
# 218                  ['cond-mat.str-el cond-mat.soft']           5
# 219                       ['cond-mat.dis-nn quant-ph']           4
# 220                                ['math.RT math.RA']           4
# 221                 ['stat.ME physics.soc-ph stat.AP']           4
# 222                ['cond-mat.mtrl-sci cond-mat.soft']           4
# 223                ['physics.comp-ph physics.chem-ph']           4
# 224                   ['physics.ed-ph physics.gen-ph']           4
# 225            ['cond-mat.mes-hall cond-mat.supr-con']           4
# 226           ['cond-mat.supr-con cond-mat.stat-mech']           4
# 227                        ['physics.gen-ph quant-ph']           4
# 228                               ['physics.plasm-ph']           4
# 229        ['q-fin.ST physics.data-an physics.soc-ph']           4
# 230                         ['astro-ph gr-qc nucl-th']           4
# 231  ['astro-ph nlin.CD physics.plasm-ph physics.sp...           3
# 232                                ['math.SG math.AG']           3
# 233                              ['q-bio.SC q-bio.CB']           3
# 234  ['cs.CE cond-mat.stat-mech cs.MS cs.NA physics...           3
# 235                     ['q-bio.PE q-bio.CB quant-ph']           3
# 236                                ['math.CV math.CA']           3
# 237  ['cond-mat.soft cond-mat.stat-mech physics.ins...           3
# 238                ['math.PR math.CA math.ST stat.TH']           3
# 239                ['physics.chem-ph physics.flu-dyn']           3
# 240                                        ['hep-lat']           3
# 241                 ['physics.atom-ph physics.gen-ph']           3
# 242                        ['math.CO math.AC math.AG']           3
# 243                ['math.ST math.PR stat.ME stat.TH']           3
# 244                                ['math.AT math.DG']           2
# 245                                ['math.OC math.CA']           2
# 246                                ['math.NT math.CV']           2
# 247              ['cond-mat.dis-nn cond-mat.mtrl-sci']           2
# 248                                        ['nlin.SI']           2
# 249                                        ['nlin.PS']           2
# 250   ['math.DG gr-qc hep-th math-ph math.AP math.MP']           2
# 251                              ['q-bio.BM q-bio.QM']           2
# 252                                ['math.PR math.AG']           2
# 253                        ['math-ph math.MP math.OA']           2
# 254                                        ['math.GM']           2
# 255                    ['cond-mat.stat-mech q-bio.PE']           2
# 256                        ['math.NT math-ph math.MP']           1
# 257                                ['math.AP math.CA']           1
# 258  ['cond-mat.stat-mech cond-mat.mtrl-sci cond-ma...           1
# 259                                ['math.CO math.RT']           1
# 260                                        ['math.CA']           1
# 261                               ['q-fin.RM math.PR']           1
# 262                              ['gr-qc astro-ph.HE']           1
# 263                                ['math.GR math.DG']           1
# 264                                ['math.GT math.AG']           1
# 265                                        ['math.MG']           1
# 266                               ['physics.class-ph']           1
# 267                                ['physics.comp-ph']           1
# 268                        ['math-ph math.GT math.MP']           1
# 269                                ['math.CV math.SP']           1
# 270                                ['math.QA math.KT']           1
# 271                        ['math.QA math-ph math.MP']           1
# 272                                ['math.RA math.RT']           1
# 273                                ['math.AG math.GR']           1
